# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import time
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd 
import numpy as np
from functools import reduce
import operator

# %% [markdown]
# ### 다나와 크롤링

# %%
def crawling(url, name, n):
    driver = webdriver.Chrome("C:/Users/rhwns/Downloads/chromedriver.exe")
    driver.get(url)
    time.sleep(1)
    
    text = []
    point = []
    date = []
    star1 = []
    date_list1 = []
    
    k = 0
    for j in range(n):           
        star1 = []
        date_list1 = []
        review = driver.find_elements_by_css_selector("div.atc")
        
        for num in range(10):
            star = driver.find_elements_by_xpath("""//*[@id="danawa-prodBlog-companyReview-content-wrap-{}"]/div[1]/span[1]/span""".format(num))
            star1.append(star)
        
        for num in range(10):
            date_list = driver.find_elements_by_xpath("/html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/ul/li[{}]/div[1]/span[2]".format(num+1))
            date_list1.append(date_list)
            
        for x, _ in enumerate(review, 1):
            text.append(_.text)
            
        for x, _ in enumerate(reduce(operator.add, star1), 1):
            point.append(_.text)
        
        for x, _ in enumerate(reduce(operator.add, date_list1), 1):
            date.append(_.text)
                                
        try:            
            time.sleep(1)
            page_num = """/html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[{}]""".format(k+1)
            print(page_num)
            driver.find_element_by_xpath(page_num).click()
            time.sleep(1)            
        except:
            try:
                if(j < 10):
                    driver.find_element_by_xpath("""/html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/a/span""").click()
                    time.sleep(1)
                    k=-1
                else:  
                    driver.find_element_by_xpath("""/html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/a[2]/span""").click()
                    time.sleep(1)
                    k=-1
            except:
                break
                                        
        k += 1
                                                                                              
    data = pd.DataFrame(text[:])
    data1 = pd.DataFrame(point[:])
    data2 = pd.DataFrame(date[:])
        
    data.to_csv("danawha/review({}).csv.".format(name),encoding='utf-8-sig')
    data1.to_csv("danawha/star({}).csv".format(name),encoding='utf-8-sig')
    data2.to_csv("danawha/date({}).csv".format(name),encoding='utf-8-sig')
    
    merge_save(name)

# %% [markdown]
# #### 리뷰 평점 날짜 합치기

# %%
def merge_save(name):
    a=pd.read_csv("danawha/review({}).csv".format(name))
    b=pd.read_csv("danawha/star({}).csv".format(name))
    c=pd.read_csv("danawha/date({}).csv".format(name))
    
    result = pd.concat([a, b, c],axis=1)
    
    result.columns = ['a', 'reviews', 'b', 'starpoint', 'c', 'date']
    del result['a']
    del result['b']
    del result['c']
    
    result.to_csv("다나와_완/{}.csv".format(name),encoding='utf-8-sig')

# %% [markdown]
# #### 차앤박 프로폴리스 앰플

# %%
crawling("http://prod.danawa.com/info/?pcode=3491024&keyword=%EC%95%B0%ED%94%8C&cate=1833218", "다나와_차앤박_프로폴앰플", 180)
# Out:
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[1]
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[2]
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[3]
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[4]
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[5]
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[6]
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[7]
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[8]
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[9]
# ...

# %% [markdown]
# #### 데저트에센스 퓨어 호호바 오일

# %%
crawling("http://prod.danawa.com/info/?pcode=5763237&keyword=%ED%98%B8%ED%98%B8%EB%B0%94%EC%98%A4%EC%9D%BC&cate=1833218", "다나와_데저트에센스_호호바오일", 32)
# Out:
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[1]
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[2]
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[3]
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[4]
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[5]
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[6]
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[7]
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[8]
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[9]
# ...

# %% [markdown]
# #### 코리아 씨밀락 골든 호호바오일

# %%
crawling("http://prod.danawa.com/info/?pcode=10034559&keyword=%ED%98%B8%ED%98%B8%EB%B0%94%EC%98%A4%EC%9D%BC&cate=1833218", "다나와_코리아씨밀락_호호바오일", 27 )
# Out:
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[1]
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[2]
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[3]
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[4]
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[5]
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[6]
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[7]
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[8]
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[9]
# ...

# %% [markdown]
# #### 싸이닉 퍼스트 컨센트레이트 앰플 (갈락토미세스, 나이아신아마이드 주성분)

# %%
crawling("http://prod.danawa.com/info/?pcode=5603180&keyword=%EA%B0%88%EB%9D%BD%ED%86%A0%EB%AF%B8%EC%84%B8%EC%8A%A4&cate=1833218","다나와_싸이닉_갈락토미나이아신앰플", 110)
# Out:
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[1]
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[2]
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[3]
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[4]
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[5]
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[6]
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[7]
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[8]
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[9]
# ...

# %% [markdown]
# #### 아임프롬 머그워트 에센스(앰플토너가 없음)

# %%
crawling("http://prod.danawa.com/info/?pcode=6247371&keyword=%EB%A8%B8%EA%B7%B8%EC%9B%8C%ED%8A%B8&cate=1833218", "다나와_아임프롬_머그워트에센스", 21)
# Out:
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[1]
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[2]
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[3]
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[4]
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[5]
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[6]
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[7]
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[8]
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[9]
# ...

# %% [markdown]
# #### SK-ll 피테라 페이셜 트리트먼트 에센스(갈락토미세스 주성분)

# %%
crawling("http://prod.danawa.com/info/?pcode=3724353&keyword=%EA%B0%88%EB%9D%BD%ED%86%A0%EB%AF%B8%EC%84%B8%EC%8A%A4&cate=1833218#bookmark_cm_opinion", "다나와_SK-2_갈락토미세스에센스", 180)
# Out:
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[1]
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[2]
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[3]
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[4]
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[5]
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[6]
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[7]
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[8]
# /html/body/div[2]/div[3]/div[2]/div[4]/div[4]/div[2]/div[2]/div[2]/div/div[3]/div[2]/div[5]/div/div/a[9]
# ...
